# %% [markdown]
# # Develop a Chatbot Using Python, NLTK, and TensorFlow

# %%
# Run this cell so you do not see GPU availibility errors from tensorflow
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %% [markdown]
# ### Task 1: Import the Required Libraries

# %%
import json
import random
import pickle

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

import numpy as np
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout, Embedding, LSTM

import matplotlib.pyplot as plt

# %% [markdown]
# ### Task 2: Load the Data

# %%
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('omw-1.4', quiet=True)

with open(r'G:\PROJECTS\NLP\chatbot\intents.json') as data:
    intents = json.loads(data.read())

# %% [markdown]
# ### Task 3: Tokenization

# %%
# Initialize necessary lists
words = []
classes = []
documents = []

# Iterate through intents 
for intent in intents['intents']:
    # Loop through each pattern in an intent
    for pattern in intent['patterns']:
        # Tokenize the pattern
        w = nltk.word_tokenize(pattern) 
        # Add tokens to the `words` list
        words.extend(w)
        # Store (tokenized words, intent tag)
        documents.append((w, intent['tag']))
        # Add unique intent tag to the list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %% [markdown]
# ### Task 4: Lemmatization

# %%
#  Initialize the WordNet Lemmatizer
lemmatizer = WordNetLemmatizer()
# List for ignored characters & Stopwords
ignore_words = ['?', '!', '.', ',']
stop_words = set(stopwords.words('english'))  # Add stopwords for better preprocessing

# Lemmatize and remove stopwords
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words and w.lower() not in stop_words]

# Remove duplicates & sort words and classes
words = sorted(set(words))
classes = sorted(set(classes))

# Save processed words
with open(r'G:\PROJECTS\NLP\chatbot\words.pkl', 'wb') as file:
    pickle.dump(words, file)

# Save processed classes
with open(r'G:\PROJECTS\NLP\chatbot\classes.pkl', 'wb') as file:
    pickle.dump(classes, file)

# %% [markdown]
# ### Task 5: Create Data for Training

# %%
# Create Data for Training
training = []
output_empty = [0] * len(classes)

# Iterate through the documents list
for doc in documents:
    bag = []
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in doc[0]] # lemmatize and lowercase each sentence
    bag = [1 if w in pattern_words else 0 for w in words] # Creates a list (bag) where 1 indicates the presence of a word and 0 means it's absent.
    # Create One-Hot Encoded Labels
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    # Add data to the training set
    training.append([bag, output_row])

# Shuffle and convert data to NumPy arrays
random.shuffle(training)
training = np.array(training, dtype='object')

# Extract features (`X_train`) and labels (`y_train`)
X_train = list(training[:, 0])
y_train = list(training[:, 1])

# Convert data to TensorFlow Dataset
X_train = np.array(X_train)
y_train = np.array(y_train)

# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Convert data to TensorFlow dataset for training
train_data = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(1024).batch(32)

# %% [markdown]
# ### Task 6: Design the Model

# %%
# Initialize the Model
model = Sequential([
    Dense(256, input_shape=(len(X_train[0]),), activation='relu'), # input layer and first hidden layer
    Dropout(0.3), # first dropout layer
    Dense(128, activation='relu'), # second hidden layer
    Dropout(0.3), # second dropout layer
    Dense(64, activation='relu'), # third hidden layer
    # Output layer
    Dense(len(y_train[0]), activation='softmax')
])
# Out:
# g:\PROJECTS\NLP\chatbot\venv\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Task 7: Train and Save the Model

# %%
# Compile the Model
model.compile(
            loss='categorical_crossentropy',
            optimizer=Adam(learning_rate=0.001), 
            metrics=['accuracy'])

# Train the Model
history = model.fit(
                    train_data, 
                    epochs=200, verbose=1,
                    validation_data=(X_val, y_val))

# Save the Model
model.save(r'G:\PROJECTS\NLP\chatbot\trained_model.keras')
# Out:
# Epoch 1/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 221ms/step - accuracy: 0
# Epoch 163/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9808 - loss: 0.0586 - val_accuracy: 0.6923 - val_loss: 0.9478
# Epoch 164/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9808 - loss: 0.0324 - val_accuracy: 0.6923 - val_loss: 0.9499
# Epoch 165/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9808 - loss: 0.0319 - val_accuracy: 0.6923 - val_loss: 0.9552
# Epoch 166/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9808 - loss: 0.0272 - val_accuracy: 0.6923 - val_loss: 0.9712
# Epoch 167/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9615 - loss: 0.0558 - val_accuracy: 0.6923 - val_loss: 0.9723
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9808 - loss: 0.0367 - val_accuracy: 0.6923 - val_loss: 0.9722
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9808 - loss: 0.0342 - val_accuracy: 0.6923 - val_loss: 0.9774
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9808 - loss: 0.0437 - val_accuracy: 0.6923 - val_loss: 0.9902
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0283 - val_accuracy: 0.6923 - val_loss: 0.9995
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9808 - loss: 0.0377 - val_accuracy: 0.6923 - val_loss: 1.0120
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9615 - loss: 0.0340 - val_accuracy: 0.6923 - val_loss: 1.0232
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0308 - val_accuracy: 0.6923 - val_loss: 1.0280
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9808 - loss: 0.0356 - val_accuracy: 0.6923 - val_loss: 1.0319
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9808 - loss: 0.0396 - val_accuracy: 0.6923 - val_loss: 1.0321
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9808 - loss: 0.0301 - val_accuracy: 0.6923 - val_loss: 1.0217
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9808 - loss: 0.0385 - val_accuracy: 0.6923 - val_loss: 1.0169
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0270 - val_accuracy: 0.6923 - val_loss: 1.0216
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9615 - loss: 0.0471 - val_accuracy: 0.6923 - val_loss: 1.0247
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9615 - loss: 0.0420 - val_accuracy: 0.6923 - val_loss: 1.0291
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9808 - loss: 0.0484 - val_accuracy: 0.6923 - val_loss: 1.0416
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9615 - loss: 0.0714 - val_accuracy: 0.6923 - val_loss: 1.0504
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 0.6923 - val_loss: 1.0581
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0270 - val_accuracy: 0.6923 - val_loss: 1.0653
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9808 - loss: 0.0372 - val_accuracy: 0.6923 - val_loss: 1.0633
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9808 - loss: 0.0240 - val_accuracy: 0.6923 - val_loss: 1.0608
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9808 - loss: 0.0365 - val_accuracy: 0.6923 - val_loss: 1.0557
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9615 - loss: 0.0501 - val_accuracy: 0.6923 - val_loss: 1.0570
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9808 - loss: 0.0519 - val_accuracy: 0.6923 - val_loss: 1.0456
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9808 - loss: 0.0320 - val_accuracy: 0.6923 - val_loss: 1.0446
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0229 - val_accuracy: 0.6923 - val_loss: 1.0500
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0216 - val_accuracy: 0.6923 - val_loss: 1.0542
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9808 - loss: 0.0418 - val_accuracy: 0.6923 - val_loss: 1.0676
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9808 - loss: 0.0202 - val_accuracy: 0.6923 - val_loss: 1.0824
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9808 - loss: 0.0364 - val_accuracy: 0.6923 - val_loss: 1.0989
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0200 - val_accuracy: 0.6923 - val_loss: 1.1074
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9808 - loss: 0.0457 - val_accuracy: 0.6923 - val_loss: 1.1044
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0268 - val_accuracy: 0.6923 - val_loss: 1.1030
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9615 - loss: 0.0308 - val_accuracy: 0.6923 - val_loss: 1.1056

# %% [markdown]
# ### Task 8: Print the Training Curves

# %%
# Set plot size and style
plt.rcParams["figure.figsize"] = (12,8)
plt.style.use("ggplot")

# Define the number of epochs for the x-axis
N = np.arange(0, 200)

# Plot the training and validation data
plt.figure()
plt.plot(N, history.history["loss"], label="train_loss")
plt.plot(N, history.history["val_loss"], label="val_loss")
plt.plot(N, history.history["accuracy"], label="train_accuracy")
plt.plot(N, history.history["val_accuracy"], label="val_accuracy")

# Add titles and labels
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
